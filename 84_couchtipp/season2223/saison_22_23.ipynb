# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ──────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
ergebnisse <- read_tsv("ergebnisse.dat")
# Out:
# Rows: 306 Columns: 6
# ── Column specification ──────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (1): debug_user
# dbl  (4): spieltag, sp_nr, tore1, tore2
# dttm (1): debug_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
ergebnisse
# Out:
#     spieltag sp_nr tore1 tore2 debug_user debug_time
# 1   1        1     1     6     Marius     2022-08-06 02:07:09
# 2   1        2     3     1     Marius     2022-08-06 17:22:31
# 3   1        3     3     1     Marius     2022-08-06 17:24:00
# 4   1        4     2     2     Marius     2022-08-06 17:27:05
# 5   1        5     1     2     Marius     2022-08-06 17:30:00
# 6   1        6     0     4     Marius     2022-08-06 17:21:18
# 7   1        7     1     0     Marius     2022-08-06 20:40:19
# 8   1        8     1     1     Marius     2022-08-07 17:34:19
# 9   1        9     3     1     Marius     2022-08-07 19:32:24
# 10  2        1     1     3     Marius     2022-08-15 00:03:49
# 11  2        2     2     2     Marius     2022-08-15 00:03:49
# 12  2        3     1     2     Marius     2022-08-15 00:03:49
# 13  2        4     1     1     Marius     2022-08-15 00:03:50
# 14  2        5     3     2     Marius     2022-08-15 00:03:50
# 15  2        6     2     2     Marius     2022-08-15 00:03:50
# 16  2        7     2     2     Marius     2022-08-15 00:03:50
# 17  2        8     0     0     Marius     2022-08-15 00:03:50
# 18  2        9     2     0     Marius     2022-08-15 00:03:50
# 19  3        1     1     0     BOT        2022-08-24 01:32:05
# 20  3        2     0     3     BOT        2022-08-24 01:32:05
# 21  3        3     0     1     BOT        2022-08-24 01:32:05
# 22  3        4     2     3     BOT        2022-08-24 01:32:05
# 23  3        5     0     0     BOT        2022-08-24 01:32:05
# 24  3        6     1     2     BOT        2022-08-24 01:32:05
# 25  3        7     2     1     BOT        2022-08-24 01:32:05
# 26  3        8     1     1     BOT        2022-08-24 01:32:05
# 27  3        9     0     7     BOT        2022-08-24 01:32:06
# 28  4        1     1     0     BOT        2022-08-28 19:30:18
# 29  4        2     1     6     BOT        2022-08-28 19:30:18
# 30  4        3     0     1     BOT        2022-08-28 19:30:18
# ⋮   ⋮        ⋮     ⋮     ⋮     ⋮          ⋮
# 277 31       7     3     1     BOT        2023-05-07 19:30:15
# 278 31       8     1     0     BOT        2023-05-07 19:30:15
# 279 31       9     0     1     BOT        2023-05-07 19:30:15
# 280 32       1     6     0     BOT        2023-05-14 19:30:14
# 281 32       2     2     1     BOT        2023-05-14 19:30:14
# 282 32       3     4     2     BOT        2023-05-14 19:30:14
# 283 32       4     1     1     BOT        2023-05-14 19:30:14
# 284 32       5     5     2     BOT        2023-05-14 19:30:14
# 285 32       6     5     2     BOT        2023-05-14 19:30:15
# 286 32       7     3     0     BOT        2023-05-14 19:30:15
# 287 32       8     3     2     BOT        2023-05-14 19:30:15
# 288 32       9     2     1     BOT        2023-05-14 19:30:15
# 289 33       1     1     1     Marius     2023-05-20 21:29:11
# 290 33       2     1     4     BOT        2023-05-21 21:30:13
# 291 33       3     2     2     BOT        2023-05-21 21:30:14
# 292 33       4     1     1     Marius     2023-05-20 21:29:11
# 293 33       5     0     3     BOT        2023-05-21 21:30:14
# 294 33       6     2     0     Marius     2023-05-20 21:29:11
# 295 33       7     2     2     Marius     2023-05-20 21:29:11
# 296 33       8     4     2     Marius     2023-05-20 21:29:11
# 297 33       9     1     3     Marius     2023-05-20 21:29:11
# 298 34       1     4     2     Marius     2023-05-27 18:03:39
# 299 34       2     1     0     Marius     2023-05-27 18:03:40
# 300 34       3     2     1     Marius     2023-05-27 18:03:40
# 301 34       4     3     0     Marius     2023-05-27 18:03:40
# 302 34       5     1     2     Marius     2023-05-27 18:03:40
# 303 34       6     1     2     Marius     2023-05-27 18:03:40
# 304 34       7     2     2     Marius     2023-05-27 18:03:40
# 305 34       8     2     0     Marius     2023-05-27 18:03:41
# 306 34       9     1     1     Marius     2023-05-27 18:03:41

# %%
ergebnisse %>% count(tore1 == tore2) %>% mutate(frac=n/sum(n))
# Out:
#   tore1 == tore2 n   frac
# 1 FALSE          231 0.754902
# 2  TRUE           75 0.245098

# %%
ergebnisse %>% count(tore1, tore2, sort=TRUE)
# Out:
#    tore1 tore2 n
# 1  1     1     38
# 2  2     1     26
# 3  2     0     22
# 4  2     2     20
# 5  1     2     19
# 6  1     0     17
# 7  3     0     16
# 8  0     0     15
# 9  0     1     15
# 10 0     2     14
# 11 3     1     14
# 12 2     3      9
# 13 0     3      8
# 14 1     3      8
# 15 3     2      8
# 16 4     0      8
# 17 4     1      6
# 18 4     2      6
# 19 5     2      6
# 20 5     0      4
# 21 1     6      3
# 22 2     4      3
# 23 5     1      3
# 24 6     0      3
# 25 1     4      2
# 26 3     3      2
# 27 6     1      2
# 28 0     4      1
# 29 0     5      1
# 30 0     7      1
# 31 1     5      1
# 32 3     4      1
# 33 4     3      1
# 34 5     3      1
# 35 6     2      1
# 36 7     1      1

# %%
tabelle <- read_tsv("tabelle.dat")
tabelle
# Out:
# Rows: 612 Columns: 9
# ── Column specification ──────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# dbl (9): team_nr, sieg, unentschieden, niederlage, punkte, tore, gegentore, ...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     team_nr sieg unentschieden niederlage punkte tore gegentore heim spieltag
# 1   1       1    0             0          3      6    1         0     1
# 2   1       1    0             0          3      2    0         1     2
# 3   1       1    0             0          3      7    0         0     3
# 4   1       0    1             0          1      1    1         1     4
# 5   1       0    1             0          1      1    1         0     5
# 6   1       0    1             0          1      2    2         1     6
# 7   1       0    0             1          0      0    1         0     7
# 8   1       1    0             0          3      4    0         1     8
# 9   1       0    1             0          1      2    2         0     9
# 10  1       1    0             0          3      5    0         1    10
# 11  1       1    0             0          3      2    0         0    11
# 12  1       1    0             0          3      6    2         1    12
# 13  1       1    0             0          3      3    2         0    13
# 14  1       1    0             0          3      6    1         1    14
# 15  1       1    0             0          3      2    0         0    15
# 16  1       0    1             0          1      1    1         0    16
# 17  1       0    1             0          1      1    1         1    17
# 18  1       0    1             0          1      1    1         1    18
# 19  1       1    0             0          3      4    2         0    19
# 20  1       1    0             0          3      3    0         1    20
# 21  1       0    0             1          0      2    3         0    21
# 22  1       1    0             0          3      3    0         1    22
# 23  1       1    0             0          3      2    1         0    23
# 24  1       1    0             0          3      5    3         1    24
# 25  1       0    0             1          0      1    2         0    25
# 26  1       1    0             0          3      4    2         1    26
# 27  1       1    0             0          3      1    0         0    27
# 28  1       0    1             0          1      1    1         1    28
# 29  1       0    0             1          0      1    3         0    29
# 30  1       1    0             0          3      2    0         1    30
# ⋮   ⋮       ⋮    ⋮             ⋮          ⋮      ⋮    ⋮         ⋮    ⋮
# 583 20      0    0             1          0      0    2         1     5
# 584 20      0    0             1          0      1    3         0     6
# 585 20      0    1             0          1      1    1         1     7
# 586 20      0    0             1          0      0    4         0     8
# 587 20      1    0             0          3      3    0         1     9
# 588 20      0    0             1          0      1    4         0    10
# 589 20      1    0             0          3      2    1         1    11
# 590 20      0    0             1          0      0    4         0    12
# 591 20      0    0             1          0      0    3         0    13
# 592 20      1    0             0          3      2    1         1    14
# 593 20      1    0             0          3      1    0         0    15
# 594 20      1    0             0          3      3    1         1    16
# 595 20      0    0             1          0      0    2         0    17
# 596 20      0    0             1          0      2    5         0    18
# 597 20      1    0             0          3      5    2         1    19
# 598 20      0    0             1          0      0    3         0    20
# 599 20      0    0             1          0      0    2         1    21
# 600 20      0    0             1          0      0    3         0    22
# 601 20      0    0             1          0      0    2         1    23
# 602 20      1    0             0          3      2    0         0    24
# 603 20      1    0             0          3      1    0         1    25
# 604 20      0    1             0          1      1    1         0    26
# 605 20      0    0             1          0      2    3         1    27
# 606 20      0    1             0          1      1    1         0    28
# 607 20      0    0             1          0      1    5         1    29
# 608 20      0    1             0          1      1    1         1    30
# 609 20      0    0             1          0      0    2         0    31
# 610 20      1    0             0          3      3    2         1    32
# 611 20      0    1             0          1      1    1         0    33
# 612 20      1    0             0          3      3    0         1    34

# %% [markdown]
# ### Graphic

# %%
theme_set(theme_light())

# %%
options(repr.plot.res=200)

# %%
library(ggrepel)

# %%
tabelle %>%
    group_by(team_nr) %>%
    mutate(cumpunkte = cumsum(punkte), team_nr=as.factor(team_nr)) %>%
    ggplot(aes(spieltag,cumpunkte,color=team_nr)) +
        geom_line(linewidth=1) +
        #geom_text_repel(mapping=aes(label=team_nr)) +
        NULL
# Out:
# plot without title

# %%
sign(c(-2,2,0,1,0))
# Out:
# [1] -1  1  0  1  0

# %% [markdown]
# ### Fixed strategy

# %%
t_fixed_strategy <- function(score1, score2, s1, s2){
    score <- if_else(score1==s1 & score2==s2, 3,
                     if_else(score1-score2 == s1-s2, 2,
                             if_else(sign(score1-score2)==sign(s1-s2), 1, 0)))
    return(sum(score))
}

# %%
# we expect 6
t_fixed_strategy(c(2,3,0,1,3), c(1,0,0,1,2), 2, 1)
# Out:
# [1] 6

# %%
t_fixed_strategy(ergebnisse$tore1, ergebnisse$tore2, 2, 1)
# Out:
# [1] 223

# %%
t_fixed_strategy(ergebnisse$tore1, ergebnisse$tore2, 1, 2)
# Out:
# [1] 149

# %%
t_fixed_strategy(ergebnisse$tore1, ergebnisse$tore2, 1, 1)
# Out:
# [1] 188

# %%
for(i in 0:3){
    for(j in 0:3){
        print(paste(i,j,t_fixed_strategy(ergebnisse$tore1, ergebnisse$tore2, i, j)))
    }
}
# Out:
# [1] "0 0 165"
# [1] "0 1 145"
# [1] "0 2 125"
# [1] "0 3 104"
# [1] "1 0 214"
# [1] "1 1 188"
# [1] "1 2 149"
# [1] "1 3 119"
# [1] "2 0 210"
# [1] "2 1 223"
# [1] "2 2 170"
# [1] "2 3 139"
# [1] "3 0 189"
# [1] "3 1 202"
# [1] "3 2 205"
# [1] "3 3 152"

# %%
ergebnisse %>%
    mutate(wer = if_else(tore1==tore2, "unentschieden", if_else(tore1>tore2, "heim", "auswärts"))) %>%
    count(wer)
# Out:
#   wer           n
# 1 auswärts       86
# 2 heim          145
# 3 unentschieden  75

# %%
team <- read_tsv("teams.dat")
# Out:
# Rows: 20 Columns: 5
# ── Column specification ──────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (4): team_name, open_db_name, city, stadium
# dbl (1): team_nr
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
team <- team %>%
    select(team_nr, team_name) %>%
    mutate(prev_season_points = c(77,42,46,38,58,45,55,46,18,33,28,42,52,28,57,69,64,33,18,42))
team
# Out:
#    team_nr team_name    prev_season_points
# 1   1      FC Bayern    77
# 2   2      Wolfsburg    42
# 3   3      Hoffenheim   46
# 4   4      Augsburg     38
# 5   5      RaBa Leipzig 58
# 6   6      M'Gladbach   45
# 7   7      Freiburg     55
# 8   8      Mainz        46
# 9   9      Schalke      18
# 10 10      Hertha       33
# 11 11      Bremen       28
# 12 12      Eintracht    42
# 13 13      FC K&ouml;ln 52
# 14 14      Bielefeld    28
# 15 15      Union        57
# 16 16      Dortmund     69
# 17 17      Leverkusen   64
# 18 18      Stuttgart    33
# 19 19      F&uuml;rth   18
# 20 20      Bochum       42

# %%
cpunkte <- tabelle %>%
    group_by(team_nr) %>%
    mutate(cumpunkte = cumsum(punkte)) %>%
    select(team_nr, spieltag, cumpunkte) %>%
    group_by(team_nr) %>%
    mutate(cumpunkte=lag(cumpunkte,default=0))

# %%
cpunkte <- cpunkte %>%
    filter(spieltag!=1) %>%
    bind_rows(team %>% transmute(team_nr, spieltag=1, cumpunkte=prev_season_points)) %>%
    arrange(team_nr, spieltag)

# %%
ergebnisse
# Out:
#     spieltag sp_nr tore1 tore2 debug_user debug_time
# 1   1        1     1     6     Marius     2022-08-06 02:07:09
# 2   1        2     3     1     Marius     2022-08-06 17:22:31
# 3   1        3     3     1     Marius     2022-08-06 17:24:00
# 4   1        4     2     2     Marius     2022-08-06 17:27:05
# 5   1        5     1     2     Marius     2022-08-06 17:30:00
# 6   1        6     0     4     Marius     2022-08-06 17:21:18
# 7   1        7     1     0     Marius     2022-08-06 20:40:19
# 8   1        8     1     1     Marius     2022-08-07 17:34:19
# 9   1        9     3     1     Marius     2022-08-07 19:32:24
# 10  2        1     1     3     Marius     2022-08-15 00:03:49
# 11  2        2     2     2     Marius     2022-08-15 00:03:49
# 12  2        3     1     2     Marius     2022-08-15 00:03:49
# 13  2        4     1     1     Marius     2022-08-15 00:03:50
# 14  2        5     3     2     Marius     2022-08-15 00:03:50
# 15  2        6     2     2     Marius     2022-08-15 00:03:50
# 16  2        7     2     2     Marius     2022-08-15 00:03:50
# 17  2        8     0     0     Marius     2022-08-15 00:03:50
# 18  2        9     2     0     Marius     2022-08-15 00:03:50
# 19  3        1     1     0     BOT        2022-08-24 01:32:05
# 20  3        2     0     3     BOT        2022-08-24 01:32:05
# 21  3        3     0     1     BOT        2022-08-24 01:32:05
# 22  3        4     2     3     BOT        2022-08-24 01:32:05
# 23  3        5     0     0     BOT        2022-08-24 01:32:05
# 24  3        6     1     2     BOT        2022-08-24 01:32:05
# 25  3        7     2     1     BOT        2022-08-24 01:32:05
# 26  3        8     1     1     BOT        2022-08-24 01:32:05
# 27  3        9     0     7     BOT        2022-08-24 01:32:06
# 28  4        1     1     0     BOT        2022-08-28 19:30:18
# 29  4        2     1     6     BOT        2022-08-28 19:30:18
# 30  4        3     0     1     BOT        2022-08-28 19:30:18
# ⋮   ⋮        ⋮     ⋮     ⋮     ⋮          ⋮
# 277 31       7     3     1     BOT        2023-05-07 19:30:15
# 278 31       8     1     0     BOT        2023-05-07 19:30:15
# 279 31       9     0     1     BOT        2023-05-07 19:30:15
# 280 32       1     6     0     BOT        2023-05-14 19:30:14
# 281 32       2     2     1     BOT        2023-05-14 19:30:14
# 282 32       3     4     2     BOT        2023-05-14 19:30:14
# 283 32       4     1     1     BOT        2023-05-14 19:30:14
# 284 32       5     5     2     BOT        2023-05-14 19:30:14
# 285 32       6     5     2     BOT        2023-05-14 19:30:15
# 286 32       7     3     0     BOT        2023-05-14 19:30:15
# 287 32       8     3     2     BOT        2023-05-14 19:30:15
# 288 32       9     2     1     BOT        2023-05-14 19:30:15
# 289 33       1     1     1     Marius     2023-05-20 21:29:11
# 290 33       2     1     4     BOT        2023-05-21 21:30:13
# 291 33       3     2     2     BOT        2023-05-21 21:30:14
# 292 33       4     1     1     Marius     2023-05-20 21:29:11
# 293 33       5     0     3     BOT        2023-05-21 21:30:14
# 294 33       6     2     0     Marius     2023-05-20 21:29:11
# 295 33       7     2     2     Marius     2023-05-20 21:29:11
# 296 33       8     4     2     Marius     2023-05-20 21:29:11
# 297 33       9     1     3     Marius     2023-05-20 21:29:11
# 298 34       1     4     2     Marius     2023-05-27 18:03:39
# 299 34       2     1     0     Marius     2023-05-27 18:03:40
# 300 34       3     2     1     Marius     2023-05-27 18:03:40
# 301 34       4     3     0     Marius     2023-05-27 18:03:40
# 302 34       5     1     2     Marius     2023-05-27 18:03:40
# 303 34       6     1     2     Marius     2023-05-27 18:03:40
# 304 34       7     2     2     Marius     2023-05-27 18:03:40
# 305 34       8     2     0     Marius     2023-05-27 18:03:41
# 306 34       9     1     1     Marius     2023-05-27 18:03:41

# %%
st <- read_tsv("spieltage.dat")
st
# Out:
# Rows: 153 Columns: 6
# ── Column specification ──────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# dbl (6): spieltag, sp_nr, team1, team2, datum1, datum2
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     spieltag sp_nr team1 team2 datum1     datum2
# 1   1        1     12     1    1659724259 1674927059
# 2   1        2     15    10    1659792659 1674916259
# 3   1        3      6     3    1659792659 1674916259
# 4   1        4      2    11    1659792659 1674916259
# 5   1        5     20     8    1659792659 1674916259
# 6   1        6      4     7    1659792659 1674916259
# 7   1        7     16    17    1659803459 1675009859
# 8   1        8     18     5    1659879059 1674847859
# 9   1        9     13     9    1659886259 1675002659
# 10  2        1      7    16    1660329059 1675521059
# 11  2        2     11    18    1660397459 1675607459
# 12  2        3     17     4    1660397459 1675452659
# 13  2        4     10    12    1660397459 1675521059
# 14  2        5      3    20    1660397459 1675521059
# 15  2        6      5    13    1660397459 1675521059
# 16  2        7      9     6    1660408259 1675531859
# 17  2        8      8    15    1660483859 1675521059
# 18  2        9      1     2    1660491059 1675614659
# 19  3        1      6    10    1660933859 1676212259
# 20  3        2     17     3    1661002259 1676125859
# 21  3        3     18     7    1661002259 1676125859
# 22  3        4     16    11    1661002259 1676125859
# 23  3        5      2     9    1661002259 1676057459
# 24  3        6      4     8    1661002259 1676125859
# 25  3        7     15     5    1661013059 1676136659
# 26  3        8     12    13    1661088659 1676219459
# 27  3        9     20     1    1661095859 1676125859
# 28  4        1      7    20    1661538659 1676730659
# 29  4        2      9    15    1661607059 1676817059
# 30  4        3     10    16    1661607059 1676824259
# ⋮   ⋮        ⋮     ⋮     ⋮     ⋮          ⋮
# 124 14       7     12     3    1668022259 1683379859
# 125 14       8     15     4    1668022259 1683379859
# 126 14       9      5     7    1668022259 1683379859
# 127 15       1      9     1    1668274259 1683984659
# 128 15       2     11     5    1668263459 1684078259
# 129 15       3      7    15    1668357059 1683984659
# 130 15       4     17    18    1668263459 1684071059
# 131 15       5      6    16    1668195059 1683995459
# 132 15       6     10    13    1668263459 1683916259
# 133 15       7      8    12    1668349859 1683984659
# 134 15       8      4    20    1668263459 1683984659
# 135 15       9      3     2    1668263459 1683984659
# 136 16       1     20    10    1674311459 1684589459
# 137 16       2     18     8    1674311459 1684675859
# 138 16       3      6    17    1674405059 1684690259
# 139 16       4     13    11    1674322259 1684589459
# 140 16       5     16     4    1674397859 1684683059
# 141 16       6      2     7    1674311459 1684521059
# 142 16       7     12     9    1674311459 1684589459
# 143 16       8     15     3    1674311459 1684589459
# 144 16       9      5     1    1674243059 1684600259
# 145 17       1      9     5    1674581459 1685194259
# 146 17       2     11    15    1674675059 1685194259
# 147 17       3      7    12    1674675059 1685194259
# 148 17       4     17    20    1674675059 1685194259
# 149 17       5      1    13    1674588659 1685194259
# 150 17       6     10     2    1674588659 1685194259
# 151 17       7      8    16    1674667859 1685194259
# 152 17       8      4     6    1674675059 1685194259
# 153 17       9      3    18    1674588659 1685194259

# %%
hinrunde <- st %>% select(spieltag, sp_nr, team1, team2, datum=datum1)
rückrunde <- st %>%
    mutate(spieltag = spieltag + 17) %>%
    select(spieltag, sp_nr, team1=team2, team2=team1, datum=datum2)
spieltage <- bind_rows(hinrunde, rückrunde)
spieltage
# Out:
#     spieltag sp_nr team1 team2 datum
# 1   1        1     12     1    1659724259
# 2   1        2     15    10    1659792659
# 3   1        3      6     3    1659792659
# 4   1        4      2    11    1659792659
# 5   1        5     20     8    1659792659
# 6   1        6      4     7    1659792659
# 7   1        7     16    17    1659803459
# 8   1        8     18     5    1659879059
# 9   1        9     13     9    1659886259
# 10  2        1      7    16    1660329059
# 11  2        2     11    18    1660397459
# 12  2        3     17     4    1660397459
# 13  2        4     10    12    1660397459
# 14  2        5      3    20    1660397459
# 15  2        6      5    13    1660397459
# 16  2        7      9     6    1660408259
# 17  2        8      8    15    1660483859
# 18  2        9      1     2    1660491059
# 19  3        1      6    10    1660933859
# 20  3        2     17     3    1661002259
# 21  3        3     18     7    1661002259
# 22  3        4     16    11    1661002259
# 23  3        5      2     9    1661002259
# 24  3        6      4     8    1661002259
# 25  3        7     15     5    1661013059
# 26  3        8     12    13    1661088659
# 27  3        9     20     1    1661095859
# 28  4        1      7    20    1661538659
# 29  4        2      9    15    1661607059
# 30  4        3     10    16    1661607059
# ⋮   ⋮        ⋮     ⋮     ⋮     ⋮
# 277 31       7      3    12    1683379859
# 278 31       8      4    15    1683379859
# 279 31       9      7     5    1683379859
# 280 32       1      1     9    1683984659
# 281 32       2      5    11    1684078259
# 282 32       3     15     7    1683984659
# 283 32       4     18    17    1684071059
# 284 32       5     16     6    1683995459
# 285 32       6     13    10    1683916259
# 286 32       7     12     8    1683984659
# 287 32       8     20     4    1683984659
# 288 32       9      2     3    1683984659
# 289 33       1     10    20    1684589459
# 290 33       2      8    18    1684675859
# 291 33       3     17     6    1684690259
# 292 33       4     11    13    1684589459
# 293 33       5      4    16    1684683059
# 294 33       6      7     2    1684521059
# 295 33       7      9    12    1684589459
# 296 33       8      3    15    1684589459
# 297 33       9      1     5    1684600259
# 298 34       1      5     9    1685194259
# 299 34       2     15    11    1685194259
# 300 34       3     12     7    1685194259
# 301 34       4     20    17    1685194259
# 302 34       5     13     1    1685194259
# 303 34       6      2    10    1685194259
# 304 34       7     16     8    1685194259
# 305 34       8      6     4    1685194259
# 306 34       9     18     3    1685194259

# %%
enriched_ergebnisse <- ergebnisse %>%
    left_join(spieltage, by=c("spieltag", "sp_nr")) %>%
    left_join(cpunkte, by=c("spieltag"="spieltag", "team1"="team_nr")) %>%
    left_join(cpunkte, by=c("spieltag"="spieltag", "team2"="team_nr")) %>%
    rename(cpunkte1 = cumpunkte.x, cpunkte2 = cumpunkte.y) %>%
    mutate(cpunkte_diff = cpunkte1 - cpunkte2)
enriched_ergebnisse
# Out:
#     spieltag sp_nr tore1 tore2 debug_user debug_time          team1 team2
# 1   1        1     1     6     Marius     2022-08-06 02:07:09 12     1
# 2   1        2     3     1     Marius     2022-08-06 17:22:31 15    10
# 3   1        3     3     1     Marius     2022-08-06 17:24:00  6     3
# 4   1        4     2     2     Marius     2022-08-06 17:27:05  2    11
# 5   1        5     1     2     Marius     2022-08-06 17:30:00 20     8
# 6   1        6     0     4     Marius     2022-08-06 17:21:18  4     7
# 7   1        7     1     0     Marius     2022-08-06 20:40:19 16    17
# 8   1        8     1     1     Marius     2022-08-07 17:34:19 18     5
# 9   1        9     3     1     Marius     2022-08-07 19:32:24 13     9
# 10  2        1     1     3     Marius     2022-08-15 00:03:49  7    16
# 11  2        2     2     2     Marius     2022-08-15 00:03:49 11    18
# 12  2        3     1     2     Marius     2022-08-15 00:03:49 17     4
# 13  2        4     1     1     Marius     2022-08-15 00:03:50 10    12
# 14  2        5     3     2     Marius     2022-08-15 00:03:50  3    20
# 15  2        6     2     2     Marius     2022-08-15 00:03:50  5    13
# 16  2        7     2     2     Marius     2022-08-15 00:03:50  9     6
# 17  2        8     0     0     Marius     2022-08-15 00:03:50  8    15
# 18  2        9     2     0     Marius     2022-08-15 00:03:50  1     2
# 19  3        1     1     0     BOT        2022-08-24 01:32:05  6    10
# 20  3        2     0     3     BOT        2022-08-24 01:32:05 17     3
# 21  3        3     0     1     BOT        2022-08-24 01:32:05 18     7
# 22  3        4     2     3     BOT        2022-08-24 01:32:05 16    11
# 23  3        5     0     0     BOT        2022-08-24 01:32:05  2     9
# 24  3        6     1     2     BOT        2022-08-24 01:32:05  4     8
# 25  3        7     2     1     BOT        2022-08-24 01:32:05 15     5
# 26  3        8     1     1     BOT        2022-08-24 01:32:05 12    13
# 27  3        9     0     7     BOT        2022-08-24 01:32:06 20     1
# 28  4        1     1     0     BOT        2022-08-28 19:30:18  7    20
# 29  4        2     1     6     BOT        2022-08-28 19:30:18  9    15
# 30  4        3     0     1     BOT        2022-08-28 19:30:18 10    16
# ⋮   ⋮        ⋮     ⋮     ⋮     ⋮          ⋮                   ⋮     ⋮
# 277 31       7     3     1     BOT        2023-05-07 19:30:15  3    12
# 278 31       8     1     0     BOT        2023-05-07 19:30:15  4    15
# 279 31       9     0     1     BOT        2023-05-07 19:30:15  7     5
# 280 32       1     6     0     BOT        2023-05-14 19:30:14  1     9
# 281 32       2     2     1     BOT        2023-05-14 19:30:14  5    11
# 282 32       3     4     2     BOT        2023-05-14 19:30:14 15     7
# 283 32       4     1     1     BOT        2023-05-14 19:30:14 18    17
# 284 32       5     5     2     BOT        2023-05-14 19:30:14 16     6
# 285 32       6     5     2     BOT        2023-05-14 19:30:15 13    10
# 286 32       7     3     0     BOT        2023-05-14 19:30:15 12     8
# 287 32       8     3     2     BOT        2023-05-14 19:30:15 20     4
# 288 32       9     2     1     BOT        2023-05-14 19:30:15  2     3
# 289 33       1     1     1     Marius     2023-05-20 21:29:11 10    20
# 290 33       2     1     4     BOT        2023-05-21 21:30:13  8    18
# 291 33       3     2     2     BOT        2023-05-21 21:30:14 17     6
# 292 33       4     1     1     Marius     2023-05-20 21:29:11 11    13
# 293 33       5     0     3     BOT        2023-05-21 21:30:14  4    16
# 294 33       6     2     0     Marius     2023-05-20 21:29:11  7     2
# 295 33       7     2     2     Marius     2023-05-20 21:29:11  9    12
# 296 33       8     4     2     Marius     2023-05-20 21:29:11  3    15
# 297 33       9     1     3     Marius     2023-05-20 21:29:11  1     5
# 298 34       1     4     2     Marius     2023-05-27 18:03:39  5     9
# 299 34       2     1     0     Marius     2023-05-27 18:03:40 15    11
# 300 34       3     2     1     Marius     2023-05-27 18:03:40 12     7
# 301 34       4     3     0     Marius     2023-05-27 18:03:40 20    17
# 302 34       5     1     2     Marius     2023-05-27 18:03:40 13     1
# 303 34       6     1     2     Marius     2023-05-27 18:03:40  2    10
# 304 34       7     2     2     Marius     2023-05-27 18:03:40 16     8
# 305 34       8     2     0     Marius     2023-05-27 18:03:41  6     4
# 306 34       9     1     1     Marius     2023-05-27 18:03:41 18     3
#     datum      cpunkte1 cpunkte2 cpunkte_diff
# 1   1659724259 42       77       -35
# 2   1659792659 57       33        24
# 3   1659792659 45       46        -1
# 4   1659792659 42       28        14
# 5   1659792659 42       46        -4
# 6   1659792659 38       55       -17
# 7   1659803459 69       64         5
# 8   1659879059 33       58       -25
# 9   1659886259 52       18        34
# 10  1660329059  3        3         0
# 11  1660397459  1        1         0
# 12  1660397459  0        0         0
# 13  1660397459  0        0         0
# 14  1660397459  0        0         0
# 15  1660397459  1        3        -2
# 16  1660408259  0        3        -3
# 17  1660483859  3        3         0
# 18  1660491059  3        1         2
# 19  1660933859  4        1         3
# 20  1661002259  0        3        -3
# 21  1661002259  2        3        -1
# 22  1661002259  6        2         4
# 23  1661002259  1        1         0
# 24  1661002259  3        4        -1
# 25  1661013059  4        2         2
# 26  1661088659  1        4        -3
# 27  1661095859  0        6        -6
# 28  1661538659  6        0         6
# 29  1661607059  2        7        -5
# 30  1661607059  1        6        -5
# ⋮   ⋮          ⋮        ⋮        ⋮
# 277 1683379859 29       43       -14
# 278 1683379859 31       56       -25
# 279 1683379859 56       54         2
# 280 1683984659 65       30        35
# 281 1684078259 57       35        22
# 282 1683984659 56       56         0
# 283 1684071059 28       48       -20
# 284 1683995459 64       39        25
# 285 1683916259 38       25        13
# 286 1683984659 43       45        -2
# 287 1683984659 28       34        -6
# 288 1683984659 46       32        14
# 289 1684589459 25       31        -6
# 290 1684675859 45       29        16
# 291 1684690259 49       39        10
# 292 1684589459 35       41        -6
# 293 1684683059 34       67       -33
# 294 1684521059 56       49         7
# 295 1684589459 30       46       -16
# 296 1684589459 32       59       -27
# 297 1684600259 68       60         8
# 298 1685194259 63       31        32
# 299 1685194259 59       36        23
# 300 1685194259 47       59       -12
# 301 1685194259 32       50       -18
# 302 1685194259 42       68       -26
# 303 1685194259 49       26        23
# 304 1685194259 70       45        25
# 305 1685194259 40       34         6
# 306 1685194259 32       35        -3

# %% [markdown]
# ### Winner Strategy

# %%
t_winner_strategy <- function(score1, score2, cdiff, s1, s2){
    tipp1 <- if_else(cdiff<0, s2, s1)
    tipp2<- if_else(cdiff<0, s1, s2)
    score <- if_else(score1==tipp1 & score2==tipp2, 3,
                     if_else(score1-score2 == tipp1-tipp2, 2,
                             if_else(sign(score1-score2)==sign(tipp1-tipp2), 1, 0)))
    return(sum(score))
}

# %%
# we expect 4
t_winner_strategy(c(2,3,0,1,3), c(1,0,0,1,2), c(1,0,-2,3,-17), 2, 1)
# Out:
# [1] 4

# %%
t_winner_strategy(
    enriched_ergebnisse$tore1,
    enriched_ergebnisse$tore2,
    enriched_ergebnisse$cpunkte_diff,
    2,
    1)
# Out:
# [1] 232

# %%
t_winner_tie_strategy <- function(score1, score2, cdiff, s1, s2){
    tipp1 <- if_else(cdiff<=0, s2, s1)
    tipp2<- if_else(cdiff<0, s1, s2)
    score <- if_else(score1==tipp1 & score2==tipp2, 3,
                     if_else(score1-score2 == tipp1-tipp2, 2,
                             if_else(sign(score1-score2)==sign(tipp1-tipp2), 1, 0)))
    return(sum(score))
}

# %%
t_winner_tie_strategy(
    enriched_ergebnisse$tore1,
    enriched_ergebnisse$tore2,
    enriched_ergebnisse$cpunkte_diff,
    2,
    1)
# Out:
# [1] 236

# %%
enriched_ergebnisse %>% count(cpunkte_diff, sort=TRUE)
# Out:
#    cpunkte_diff n
# 1    0          32
# 2   -6          18
# 3   -1          15
# 4    4          13
# 5   -3          11
# 6   -2          10
# 7    1          10
# 8    2          10
# 9    3          10
# 10   5          10
# 11   7          10
# 12 -12           9
# 13   8           9
# 14  -8           8
# 15  -7           8
# 16  -5           8
# 17  -4           7
# 18   6           7
# 19 -10           6
# 20  13           6
# 21  15           6
# 22 -18           5
# 23  23           5
# 24 -15           4
# 25   9           4
# 26  12           4
# 27  18           4
# 28  25           4
# 29 -33           3
# 30 -27           3
# 31 -17           3
# 32 -16           3
# 33 -13           3
# 34  -9           3
# 35  10           3
# 36  22           3
# 37 -23           2
# 38 -20           2
# 39 -19           2
# 40 -14           2
# 41 -11           2
# 42  16           2
# 43  30           2
# 44 -30           1
# 45 -26           1
# 46 -25           1
# 47 -24           1
# 48 -22           1
# 49  14           1
# 50  17           1
# 51  19           1
# 52  20           1
# 53  21           1
# 54  26           1
# 55  28           1
# 56  32           1
# 57  35           1
# 58  37           1

# %%
enriched_ergebnisse %>% mutate(ncd = cpunkte_diff/spieltag)
# Out:
#     spieltag sp_nr tore1 tore2 debug_user debug_time          team1 team2
# 1   1        1     1     6     Marius     2022-08-06 02:07:09 12     1
# 2   1        2     3     1     Marius     2022-08-06 17:22:31 15    10
# 3   1        3     3     1     Marius     2022-08-06 17:24:00  6     3
# 4   1        4     2     2     Marius     2022-08-06 17:27:05  2    11
# 5   1        5     1     2     Marius     2022-08-06 17:30:00 20     8
# 6   1        6     0     4     Marius     2022-08-06 17:21:18  4     7
# 7   1        7     1     0     Marius     2022-08-06 20:40:19 16    17
# 8   1        8     1     1     Marius     2022-08-07 17:34:19 18     5
# 9   1        9     3     1     Marius     2022-08-07 19:32:24 13     9
# 10  2        1     1     3     Marius     2022-08-15 00:03:49  7    16
# 11  2        2     2     2     Marius     2022-08-15 00:03:49 11    18
# 12  2        3     1     2     Marius     2022-08-15 00:03:49 17     4
# 13  2        4     1     1     Marius     2022-08-15 00:03:50 10    12
# 14  2        5     3     2     Marius     2022-08-15 00:03:50  3    20
# 15  2        6     2     2     Marius     2022-08-15 00:03:50  5    13
# 16  2        7     2     2     Marius     2022-08-15 00:03:50  9     6
# 17  2        8     0     0     Marius     2022-08-15 00:03:50  8    15
# 18  2        9     2     0     Marius     2022-08-15 00:03:50  1     2
# 19  3        1     1     0     BOT        2022-08-24 01:32:05  6    10
# 20  3        2     0     3     BOT        2022-08-24 01:32:05 17     3
# 21  3        3     0     1     BOT        2022-08-24 01:32:05 18     7
# 22  3        4     2     3     BOT        2022-08-24 01:32:05 16    11
# 23  3        5     0     0     BOT        2022-08-24 01:32:05  2     9
# 24  3        6     1     2     BOT        2022-08-24 01:32:05  4     8
# 25  3        7     2     1     BOT        2022-08-24 01:32:05 15     5
# 26  3        8     1     1     BOT        2022-08-24 01:32:05 12    13
# 27  3        9     0     7     BOT        2022-08-24 01:32:06 20     1
# 28  4        1     1     0     BOT        2022-08-28 19:30:18  7    20
# 29  4        2     1     6     BOT        2022-08-28 19:30:18  9    15
# 30  4        3     0     1     BOT        2022-08-28 19:30:18 10    16
# ⋮   ⋮        ⋮     ⋮     ⋮     ⋮          ⋮                   ⋮     ⋮
# 277 31       7     3     1     BOT        2023-05-07 19:30:15  3    12
# 278 31       8     1     0     BOT        2023-05-07 19:30:15  4    15
# 279 31       9     0     1     BOT        2023-05-07 19:30:15  7     5
# 280 32       1     6     0     BOT        2023-05-14 19:30:14  1     9
# 281 32       2     2     1     BOT        2023-05-14 19:30:14  5    11
# 282 32       3     4     2     BOT        2023-05-14 19:30:14 15     7
# 283 32       4     1     1     BOT        2023-05-14 19:30:14 18    17
# 284 32       5     5     2     BOT        2023-05-14 19:30:14 16     6
# 285 32       6     5     2     BOT        2023-05-14 19:30:15 13    10
# 286 32       7     3     0     BOT        2023-05-14 19:30:15 12     8
# 287 32       8     3     2     BOT        2023-05-14 19:30:15 20     4
# 288 32       9     2     1     BOT        2023-05-14 19:30:15  2     3
# 289 33       1     1     1     Marius     2023-05-20 21:29:11 10    20
# 290 33       2     1     4     BOT        2023-05-21 21:30:13  8    18
# 291 33       3     2     2     BOT        2023-05-21 21:30:14 17     6
# 292 33       4     1     1     Marius     2023-05-20 21:29:11 11    13
# 293 33       5     0     3     BOT        2023-05-21 21:30:14  4    16
# 294 33       6     2     0     Marius     2023-05-20 21:29:11  7     2
# 295 33       7     2     2     Marius     2023-05-20 21:29:11  9    12
# 296 33       8     4     2     Marius     2023-05-20 21:29:11  3    15
# 297 33       9     1     3     Marius     2023-05-20 21:29:11  1     5
# 298 34       1     4     2     Marius     2023-05-27 18:03:39  5     9
# 299 34       2     1     0     Marius     2023-05-27 18:03:40 15    11
# 300 34       3     2     1     Marius     2023-05-27 18:03:40 12     7
# 301 34       4     3     0     Marius     2023-05-27 18:03:40 20    17
# 302 34       5     1     2     Marius     2023-05-27 18:03:40 13     1
# 303 34       6     1     2     Marius     2023-05-27 18:03:40  2    10
# 304 34       7     2     2     Marius     2023-05-27 18:03:40 16     8
# 305 34       8     2     0     Marius     2023-05-27 18:03:41  6     4
# 306 34       9     1     1     Marius     2023-05-27 18:03:41 18     3
#     datum      cpunkte1 cpunkte2 cpunkte_diff ncd
# 1   1659724259 0        0         0            0.0000000
# 2   1659792659 0        0         0            0.0000000
# 3   1659792659 0        0         0            0.0000000
# 4   1659792659 0        0         0            0.0000000
# 5   1659792659 0        0         0            0.0000000
# 6   1659792659 0        0         0            0.0000000
# 7   1659803459 0        0         0            0.0000000
# 8   1659879059 0        0         0            0.0000000
# 9   1659886259 0        0         0            0.0000000
# 10  1660329059 3        3         0            0.0000000
# 11  1660397459 1        1         0            0.0000000
# 12  1660397459 0        0         0            0.0000000
# 13  1660397459 0        0         0            0.0000000
# 14  1660397459 0        0         0            0.0000000
# 15  1660397459 1        3        -2           -1.0000000
# 16  1660408259 0        3        -3           -1.5000000
# 17  1660483859 3        3         0            0.0000000
# 18  1660491059 3        1         2            1.0000000
# 19  1660933859 4        1         3            1.0000000
# 20  1661002259 0        3        -3           -1.0000000
# 21  1661002259 2        3        -1           -0.3333333
# 22  1661002259 6        2         4            1.3333333
# 23  1661002259 1        1         0            0.0000000
# 24  1661002259 3        4        -1           -0.3333333
# 25  1661013059 4        2         2            0.6666667
# 26  1661088659 1        4        -3           -1.0000000
# 27  1661095859 0        6        -6           -2.0000000
# 28  1661538659 6        0         6            1.5000000
# 29  1661607059 2        7        -5           -1.2500000
# 30  1661607059 1        6        -5           -1.2500000
# ⋮   ⋮          ⋮        ⋮        ⋮            ⋮
# 277 1683379859 29       43       -14          -0.45161290
# 278 1683379859 31       56       -25          -0.80645161
# 279 1683379859 56       54         2           0.06451613
# 280 1683984659 65       30        35           1.09375000
# 281 1684078259 57       35        22           0.68750000
# 282 1683984659 56       56         0           0.00000000
# 283 1684071059 28       48       -20          -0.62500000
# 284 1683995459 64       39        25           0.78125000
# 285 1683916259 38       25        13           0.40625000
# 286 1683984659 43       45        -2          -0.06250000
# 287 1683984659 28       34        -6          -0.18750000
# 288 1683984659 46       32        14           0.43750000
# 289 1684589459 25       31        -6          -0.18181818
# 290 1684675859 45       29        16           0.48484848
# 291 1684690259 49       39        10           0.30303030
# 292 1684589459 35       41        -6          -0.18181818
# 293 1684683059 34       67       -33          -1.00000000
# 294 1684521059 56       49         7           0.21212121
# 295 1684589459 30       46       -16          -0.48484848
# 296 1684589459 32       59       -27          -0.81818182
# 297 1684600259 68       60         8           0.24242424
# 298 1685194259 63       31        32           0.94117647
# 299 1685194259 59       36        23           0.67647059
# 300 1685194259 47       59       -12          -0.35294118
# 301 1685194259 32       50       -18          -0.52941176
# 302 1685194259 42       68       -26          -0.76470588
# 303 1685194259 49       26        23           0.67647059
# 304 1685194259 70       45        25           0.73529412
# 305 1685194259 40       34         6           0.17647059
# 306 1685194259 32       35        -3          -0.08823529

# %%
enriched_ergebnisse$cpunkte_diff %>% sum
# Out:
# [1] -6

# %% [markdown]
# ## Tipp Statistiken

# %%
tipps <- read_tsv("tipps.dat")
# Out:
# Rows: 11124 Columns: 5
# ── Column specification ──────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# dbl (5): spieltag, sp_nr, user_nr, tore1, tore2
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
tipps %>% count(tore1, tore2, sort=T)
# Out:
#    tore1 tore2 n
# 1   2     1    2642
# 2   1     2    1867
# 3   1     1    1030
# 4   3     1     852
# 5   2     0     813
# 6   1     3     680
# 7   2     2     577
# 8   0     2     510
# 9   1     0     379
# 10  3     0     280
# 11  0     1     236
# 12  3     2     222
# 13  0     3     195
# 14  2     3     158
# 15  4     1     135
# 16  1     4     106
# 17  4     0      76
# 18  0     0      72
# 19  0     4      50
# 20  2     4      42
# 21  4     2      32
# 22  1     5      24
# 23  0     5      19
# 24  5     1      19
# 25  3     3      17
# 26  5     0      13
# 27  5     2      12
# 28  4     3      11
# 29  2     5       7
# 30  0     6       6
# 31  3     4       5
# 32  2     6       4
# 33  4     5       3
# 34  1     6       2
# 35  3     5       2
# 36  6     0       2
# 37  6     1       2
# 38  6     2       2
# 39  6     5       2
# 40  0     7       1
# 41  1    69       1
# 42  2     9       1
# 43  2    12       1
# 44  3     6       1
# 45  4     4       1
# 46  5     3       1
# 47  5     4       1
# 48  5     7       1
# 49  8     7       1
# 50  9     0       1
# 51 10     9       1
# 52 12    11       1
# 53 14    13       1
# 54 16    15       1
# 55 18     0       1
# 56 18    17       1
# 57 53     0       1

# %%
tipps %>% mutate(absdiff = abs(tore1-tore2)) %>% count(absdiff, sort=T)
# Out:
#    absdiff n
# 1   1      5532
# 2   2      2933
# 3   0      1697
# 4   3       736
# 5   4       175
# 6   5        36
# 7   6         8
# 8   7         2
# 9   9         1
# 10 10         1
# 11 18         1
# 12 53         1
# 13 68         1

# %%
enriched_ergebnisse %>% filter(spieltag==20, sp_nr==3)
# Out:
#   spieltag sp_nr tore1 tore2 debug_user debug_time          team1 team2
# 1 20       3     2     1     BOT        2023-02-12 19:30:20 7     18
#   datum      cpunkte1 cpunkte2 cpunkte_diff
# 1 1676125859 34       16       18

# %%
tipps %>% inner_join(
    enriched_ergebnisse %>% select(spieltag, sp_nr, tore1, tore2)) %>%
    count(spieltag, sp_nr, sort=T)
# Out:
# Joining with `by = join_by(spieltag, sp_nr, tore1, tore2)`
#     spieltag sp_nr n
# 1   20       3     22
# 2    8       3     17
# 3   14       3     16
# 4   23       6     16
# 5   24       9     16
# 6   28       1     16
# 7   12       8     15
# 8   19       8     15
# 9   17       2     14
# 10  27       8     14
# 11  32       9     14
# 12   3       6     13
# 13  13       1     13
# 14  34       3     13
# 15  13       8     12
# 16  15       2     12
# 17  15       9     12
# 18  32       2     12
# 19   5       4     10
# 20  11       6     10
# 21  12       1     10
# 22  33       4     10
# 23   1       5      9
# 24  14       5      9
# 25  23       1      9
# 26  30       4      9
# 27  12       3      8
# 28  13       5      8
# 29  17       4      8
# 30  17       7      8
# ⋮   ⋮        ⋮     ⋮
# 143  5       1     1
# 144  6       1     1
# 145  7       9     1
# 146  8       5     1
# 147 10       6     1
# 148 11       2     1
# 149 12       6     1
# 150 17       8     1
# 151 19       2     1
# 152 20       5     1
# 153 22       1     1
# 154 22       3     1
# 155 23       4     1
# 156 23       5     1
# 157 23       7     1
# 158 25       7     1
# 159 27       4     1
# 160 27       5     1
# 161 27       6     1
# 162 27       7     1
# 163 28       3     1
# 164 28       4     1
# 165 29       5     1
# 166 30       2     1
# 167 30       8     1
# 168 31       7     1
# 169 32       1     1
# 170 33       3     1
# 171 33       5     1
# 172 34       7     1

# %%
enriched_tipps <- tipps %>% left_join(
    enriched_ergebnisse %>% select(spieltag, sp_nr, tore1, tore2), by=c("spieltag","sp_nr"))
enriched_tipps
# Out:
#       spieltag sp_nr user_nr tore1.x tore2.x tore1.y tore2.y
# 1     1        1      2      3       2       1       6
# 2     1        1      3      2       1       1       6
# 3     1        1      4      2       1       1       6
# 4     1        1      5      1       2       1       6
# 5     1        1      7      2       1       1       6
# 6     1        1      8      3       2       1       6
# 7     1        1      9      3       1       1       6
# 8     1        1     10      1       2       1       6
# 9     1        1     11      2       1       1       6
# 10    1        1     12      2       2       1       6
# 11    1        1     13      1       3       1       6
# 12    1        1     14      2       1       1       6
# 13    1        1     17      3       1       1       6
# 14    1        1     20      2       1       1       6
# 15    1        1     24      2       2       1       6
# 16    1        1     32      2       1       1       6
# 17    1        1     34      3       2       1       6
# 18    1        1     35      1       3       1       6
# 19    1        1     36      2       2       1       6
# 20    1        1     37      2       1       1       6
# 21    1        1     42      1       3       1       6
# 22    1        1     43      1       3       1       6
# 23    1        1     45      1       4       1       6
# 24    1        1     46      2       1       1       6
# 25    1        1     47      3       2       1       6
# 26    1        1     49      2       1       1       6
# 27    1        1     50      2       1       1       6
# 28    1        1     51      2       1       1       6
# 29    1        1     52      3       2       1       6
# 30    1        1     54      2       3       1       6
# ⋮     ⋮        ⋮     ⋮       ⋮       ⋮       ⋮       ⋮
# 11095 34       9      4      2       1       1       1
# 11096 34       9      5      2       0       1       1
# 11097 34       9      7      2       1       1       1
# 11098 34       9      8      2       1       1       1
# 11099 34       9      9      2       1       1       1
# 11100 34       9     10      2       1       1       1
# 11101 34       9     11      2       1       1       1
# 11102 34       9     12      2       1       1       1
# 11103 34       9     13      2       1       1       1
# 11104 34       9     14      1       1       1       1
# 11105 34       9     20      1       2       1       1
# 11106 34       9     24      1       1       1       1
# 11107 34       9     34      2       0       1       1
# 11108 34       9     35      1       1       1       1
# 11109 34       9     37      1       2       1       1
# 11110 34       9     42      2       1       1       1
# 11111 34       9     43      2       1       1       1
# 11112 34       9     45      2       2       1       1
# 11113 34       9     46      2       1       1       1
# 11114 34       9     49      2       1       1       1
# 11115 34       9     50      2       1       1       1
# 11116 34       9     51      2       0       1       1
# 11117 34       9     52      2       2       1       1
# 11118 34       9     55      3       2       1       1
# 11119 34       9     56      2       1       1       1
# 11120 34       9     57      2       1       1       1
# 11121 34       9     58      2       1       1       1
# 11122 34       9     61      3       2       1       1
# 11123 34       9     62      5       1       1       1
# 11124 34       9     63      2       1       1       1

# %%
enriched_ergebnisse %>% filter(spieltag==2, sp_nr==9)
# Out:
#   spieltag sp_nr tore1 tore2 debug_user debug_time          team1 team2
# 1 2        9     2     0     Marius     2022-08-15 00:03:50 1     2
#   datum      cpunkte1 cpunkte2 cpunkte_diff
# 1 1660491059 3        1        2

# %%
enriched_tipps %>%
    filter(sign(tore1.x-tore2.x)==sign(tore1.y-tore2.y)) %>%
    count(spieltag,sp_nr, sort=T)
# Out:
#     spieltag sp_nr n
# 1    2       9     39
# 2    3       9     38
# 3    4       1     38
# 4   13       5     38
# 5   13       6     38
# 6   15       1     38
# 7   16       5     37
# 8   19       4     37
# 9   20       9     37
# 10  21       3     37
# 11  22       1     37
# 12   4       3     36
# 13   7       4     36
# 14  11       5     36
# 15  13       4     36
# 16  14       7     36
# 17  15       4     36
# 18  23       2     36
# 19  23       3     36
# 20  24       5     36
# 21  24       9     36
# 22  25       6     36
# 23  12       4     35
# 24  13       2     35
# 25  14       4     35
# 26  17       4     35
# 27  21       9     35
# 28  28       8     35
# 29   5       1     34
# 30   8       4     34
# ⋮   ⋮        ⋮     ⋮
# 264 33       3     3
# 265 34       6     3
# 266  1       8     2
# 267  2       4     2
# 268  2       6     2
# 269  6       9     2
# 270 14       6     2
# 271 18       4     2
# 272 19       3     2
# 273 19       7     2
# 274 20       1     2
# 275 21       4     2
# 276 27       2     2
# 277 28       4     2
# 278 28       5     2
# 279 31       5     2
# 280 31       7     2
# 281  3       8     1
# 282  4       7     1
# 283  5       9     1
# 284  8       6     1
# 285  9       1     1
# 286 11       2     1
# 287 21       2     1
# 288 21       7     1
# 289 25       4     1
# 290 30       8     1
# 291 33       7     1
# 292 33       9     1
# 293 34       7     1
